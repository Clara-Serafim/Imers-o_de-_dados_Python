# %%
'cinza'
# Out:
# 'cinza'

# %%
'clara'
# Out:
# 'clara'

# %%
'u2'
# Out:
# 'u2'

# %%
print('Boas vindas a aula de python')
# Out:
# Boas vindas a aula de python

# %%
'variaveis'
# Out:
# 'variaveis'

# %%
nome = 'clara'

# %%
nome
# Out:
# 'clara'

# %%
cor favorita = 'cinza'
# Out:
#   File "/tmp/ipython-input-3663807695.py", line 1
#     cor favorita = 'cinza'
#         ^
# SyntaxError: invalid syntax

# %%
cor_favorita = 'cinza'

# %%
cor_favorita_da_clara

# %%
print(nome, cor_favorita)

# %%
saldo = 5000

# %%
saldo
# Out:
# 13000

# %%
saldo = saldo + 2000

# %%
saldo
# Out:
# 15000

# %%
print('R$', saldo)
# Out:
# R$ 15000

# %%
print(' saldo na sua conta: R$', saldo)
# Out:
#  saldo na sua conta: R$ 15000

# %%
saldo = saldo- 500

# %%
print(' saldo na sua conta: R$', saldo)
# Out:
#  saldo na sua conta: R$ 14500

# %%
saldo = saldo * 2

# %%
print(' saldo na sua conta: R$', saldo)
# Out:
#  saldo na sua conta: R$ 29000

# %%
import this

# %%
tenis_nike = 250

# %%
a = 250

# %%
idade = 18
# se idade for maior que 16
if idade >=18:
# pode dirigir
  print('pode dirigir')
# senão
else:
# não pode dirigir
  print('não pode dirigir')
# Out:
# pode dirigir

# %%
# isso é m cometário
